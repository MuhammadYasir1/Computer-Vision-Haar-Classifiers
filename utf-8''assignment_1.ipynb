# %% [markdown]
# # Assignment 1: Building a Better Contact Sheet
# In the lectures for this week you were shown how to make a contact sheet for digital photographers, and how you can take one image and create nine different variants based on the brightness of that image. In this assignment you are going to change the colors of the image, creating variations based on a single photo. There are many complex ways to change a photograph using variations, such as changing a black and white image to either "cool" variants, which have light purple and blues in them, or "warm" variants, which have touches of yellow and may look sepia toned. In this assignment, you'll be just changing the image one color channel at a time
#
# Your assignment is to learn how to take the stub code provided in the lecture (cleaned up below), and generate the following output image:
#
# ![](./readonly/assignment1.png "")
#
# From the image you can see there are two parameters which are being varied for each sub-image. First, the rows are changed by color channel, where the top is the red channel, the middle is the green channel, and the bottom is the blue channel. Wait, why don't the colors look more red, green, and blue, in that order? Because the change you to be making is the ratio, or intensity, or that channel, in relationship to the other channels. We're going to use three different intensities, 0.1 (reduce the channel a lot), 0.5 (reduce the channel in half), and 0.9 (reduce the channel only a little bit).
#
# For instance, a pixel represented as (200, 100, 50) is a sort of burnt orange color. So the top row of changes would create three alternative pixels, varying the first channel (red). one at (20, 100, 50), one at (100, 100, 50), and one at (180, 100, 50). The next row would vary the second channel (blue), and would create pixels of color values (200, 10, 50), (200, 50, 50) and (200, 90, 50).
#
# Note: A font is included for your usage if you would like! It's located in the file `readonly/fanwood-webfont.ttf`
#
# Need some hints? Use them sparingly, see how much you can get done on your own first! The sample code given in the class has been cleaned up below, you might want to start from that.

# %%
import PIL
import inspect
from PIL import Image
from PIL import ImageEnhance
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImagePalette
from PIL import ImageColor
from IPython.display import display
fnt = ImageFont.truetype("readonly/fanwood-webfont.ttf", 60)


x=0
y=0
channel=0
intensity=0.1
xy=(30,30)
# read image and convert to RGB
image=Image.open("readonly/msi_recruitment.gif")
image=image.convert('RGB')
copy1=image.copy()

#display(image)

for ite in range(copy1.width):
    for ite2 in range(copy1.height):
        tup1=copy1.getpixel((ite,ite2))
        tup2=(0.1,1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy1.putpixel((ite,ite2),tuple(res))

print('done')

copy2=image.copy()

for ite in range(copy2.width):
    for ite2 in range(copy2.height):
        tup1=copy2.getpixel((ite,ite2))
        tup2=(0.5,1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy2.putpixel((ite,ite2),tuple(res))

print('done')

copy3=image.copy()

for ite in range(copy3.width):
    for ite2 in range(copy3.height):
        tup1=copy3.getpixel((ite,ite2))
        tup2=(1,1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy3.putpixel((ite,ite2),tuple(res))
print('done')

copy4=image.copy()

for ite in range(copy4.width):
    for ite2 in range(copy4.height):
        tup1=copy4.getpixel((ite,ite2))
        tup2=(1,0.1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy4.putpixel((ite,ite2),tuple(res))

print('done')

copy5=image.copy()

for ite in range(copy5.width):
    for ite2 in range(copy5.height):
        tup1=copy5.getpixel((ite,ite2))
        tup2=(1,0.5,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy5.putpixel((ite,ite2),tuple(res))

print('done')

copy6=image.copy()

for ite in range(copy6.width):
    for ite2 in range(copy6.height):
        tup1=copy6.getpixel((ite,ite2))
        tup2=(1,1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy6.putpixel((ite,ite2),tuple(res))

print('done')


copy7=image.copy()

for ite in range(copy7.width):
    for ite2 in range(copy7.height):
        tup1=copy7.getpixel((ite,ite2))
        tup2=(1,1,0.1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy7.putpixel((ite,ite2),tuple(res))

print('done')

copy8=image.copy()

for ite in range(copy8.width):
    for ite2 in range(copy8.height):
        tup1=copy8.getpixel((ite,ite2))
        tup2=(1,1,0.5)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy8.putpixel((ite,ite2),tuple(res))

print('done')

copy9=image.copy()

for ite in range(copy9.width):
    for ite2 in range(copy9.height):
        tup1=copy9.getpixel((ite,ite2))
        tup2=(1,1,1)
        res = tuple(int(ele1) * int(ele2) for ele1, ele2 in zip(tup1,tup2))
        copy9.putpixel((ite,ite2),tuple(res))

print('done')


images=[copy1,copy2,copy3,copy4,copy5,copy6,copy7,copy8,copy9]


#for i in range(1, 10):
 #   images.append(image)
    
    
    
# create a contact sheet from different brightnesses
first_image=images[0]
contact_sheet=PIL.Image.new(first_image.mode, (first_image.width*3,first_image.height*3))


for img in images:
    
        
        
    
    if x == 0:
        intensity = 0.1
        
    elif x == first_image.width :
        intensity= 0.5
    elif x == 2*first_image.width:
        intensity =0.9
    
    if y==0:
        chanenel=0
    elif y == first_image.height:
        channel= 1
    elif y == 2*first_image.height:
        channel=2
    
    bbox=ImageDraw.Draw(img)
    bbox.rectangle((0,400,800,450,),fill='black')
    text1=ImageDraw.Draw(img)
    text1.text((img.width-750,img.height-55),'channel {} intensity {} '.format(channel,intensity) , font=fnt, fill='White')
  
    # Lets paste the current image into the contact sheet
    
    contact_sheet.paste(img, (x, y) )
    # Now we update our X position. If it is going to be the width of the image, then we set it to 0
    # and update Y as well to point to the next "line" of the contact sheet.
    if x+first_image.width == contact_sheet.width:
        x=0
        y=y+first_image.height
        
    else:
        x=x+first_image.width
       
   


# resize and display the contact sheet
contact_sheet = contact_sheet.resize((int(contact_sheet.width/2),int(contact_sheet.height/2) ))
display(contact_sheet)
#help(Image)
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7FB2DC5384E0>

# %% [markdown]
# ## HINT 1
#
# Check out the `PIL.ImageDraw module` for helpful functions

# %% [markdown]
# ## HINT 2
#
# Did you find the `text()` function of `PIL.ImageDraw`?

# %% [markdown]
# ## HINT 3
#
# Have you seen the `PIL.ImageFont` module? Try loading the font with a size of 75 or so.

# %% [markdown]
# ## HINT 4
# These hints aren't really enough, we should probably generate some more.
